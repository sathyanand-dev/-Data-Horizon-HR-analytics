# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('F:\DCS-SEM 5\HR Lab\Ex 11.xlsx' , sheet_name = 'Recuirtment')
df.head()
# Out:
#    Id          Name  Age    Position  Channel  Talent Level  Projects Done  \
# 0   1   Emily Smith   32     Manager        2             6              5
# 1   2  Liam Johnson   27     Analyst        3             6              3
# 2   3  Olivia Brown   38    Employee        3             9              4
# 3   4    Noah Davis   36  Supervisor        3             6              5
# 4   5    Ava Wilson   32     Analyst        4             6              4
#
#    Experinence in hand
# 0                    3
# 1                    3
# 2                    2
# 3                    2
# 4                    3

# %%
df.dtypes
# Out:
# Id                      int64
# Name                   object
# Age                     int64
# Position               object
# Channel                 int64
# Talent Level            int64
# Projects Done           int64
# Experinence in hand     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'Name', 'Age', 'Position', 'Channel', 'Talent Level',
#        'Projects Done', 'Experinence in hand'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Id         Age     Channel  Talent Level  Projects Done  \
# count  300.000000  300.000000  300.000000    300.000000     300.000000
# mean    75.500000   32.573333    2.573333      7.940000       3.560000
# std     43.372656    3.599232    1.108476      1.441061       1.103233
# min      1.000000   27.000000    1.000000      6.000000       2.000000
# 25%     38.000000   30.000000    2.000000      7.000000       3.000000
# 50%     75.500000   32.000000    3.000000      8.000000       4.000000
# 75%    113.000000   36.000000    4.000000      9.000000       5.000000
# max    150.000000   38.000000    4.000000     10.000000       5.000000
#
#        Experinence in hand
# count           300.000000
# mean              1.966667
# std               0.804807
# min               1.000000
# 25%               1.000000
# 50%               2.000000
# 75%               3.000000
# max               3.000000

# %%
df.count()
# Out:
# Id                     300
# Name                   300
# Age                    300
# Position               300
# Channel                300
# Talent Level           300
# Projects Done          300
# Experinence in hand    300
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id                     0
# Name                   0
# Age                    0
# Position               0
# Channel                0
# Talent Level           0
# Projects Done          0
# Experinence in hand    0
# dtype: int64

# %%
for i in df.columns:
    sns.histplot(df[i])
    plt.show()

# %%
for i in df.columns:
    if len(list(df[i].unique())) < 7:
        plt.bar(df[i].unique() , df[i].value_counts())
        plt.title(i)
        plt.show()

# %%
corr = df[["Channel" , "Talent Level" ,"Projects Done" , "Experinence in hand"]].corr()
plt.figure(figsize = (5 , 5))
sns.heatmap(corr , annot = True)
plt.show()

# %%
df['Channel'].value_counts()
# Out:
# Channel
# 3    85
# 4    78
# 1    69
# 2    68
# Name: count, dtype: int64

# %%
df['Talent Level'].value_counts()
# Out:
# Talent Level
# 6     72
# 8     65
# 9     59
# 10    57
# 7     47
# Name: count, dtype: int64

# %%
df['Projects Done'].value_counts()
# Out:
# Projects Done
# 4    82
# 5    77
# 3    73
# 2    68
# Name: count, dtype: int64

# %%
df['Experinence in hand'].value_counts()
# Out:
# Experinence in hand
# 2    106
# 1    102
# 3     92
# Name: count, dtype: int64
